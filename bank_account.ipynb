# %%
import random

class BankAccount:
    def __init__(self, name, balance):
        self.account_number = str(random.randint(10**6, 10**7 - 1))  # 7-digit number
        self.name = name
        self.balance = balance

    def deposit(self, amt):
        self.balance += amt
        print("Deposited:", amt)

    def withdraw(self, amt):
        if amt <= self.balance:
            self.balance -= amt
            print("Withdrawn:", amt)
        else:
            print("Insufficient balance")

class SavingAccount(BankAccount):
    rate = 4
    def apply_interest(self):
        interest = self.balance * self.rate / 100
        self.balance += interest
        print("Interest added:", interest)

class CurrentAccount(BankAccount):
    limit = 50000
    def withdraw(self, amt):
        if amt <= self.balance + self.limit:
            self.balance -= amt
            print("Withdrawn:", amt)
        else:
            print("Insufficient balance")

# --- Main Program ---
acc_type = input("Enter account type (saving/current): ").lower()
name = input("Enter account holder name: ")
balance = float(input("Enter initial balance: "))

if acc_type == "saving":
    acc = SavingAccount(name, balance)
    print("Account Number:", acc.account_number)
    print("Interest Rate:", acc.rate, "%")
elif acc_type == "current":
    acc = CurrentAccount(name, balance)
    print("Account Number:", acc.account_number)
    print("Overdraft Limit: ₹", acc.limit)
else:
    print("Invalid account type")
    exit()

while True:
    if acc_type == "saving":
        print("\n1.Deposit  2.Withdraw  3.Balance  4.Apply Interest  5.Exit")
    else:
        print("\n1.Deposit  2.Withdraw  3.Balance  5.Exit")

    ch = input("Enter choice: ")
    if ch == "1":
        amt = float(input("Amount: "))
        acc.deposit(amt)
    elif ch == "2":
        amt = float(input("Amount: "))
        acc.withdraw(amt)
    elif ch == "3":
        print("Balance:", acc.balance)
    elif ch == "4" and acc_type == "saving":
        acc.apply_interest()
    elif ch == "5":
        break
    else:
        print("Invalid choice")
# Out:
# Enter account type (saving/current): saving
# Enter account holder name: Anshika
# Enter initial balance: 120
# Account Number: 2412000
# Interest Rate: 4 %
#
# 1.Deposit  2.Withdraw  3.Balance  4.Apply Interest  5.Exit
# Enter choice: 3
# Balance: 120.0
#
# 1.Deposit  2.Withdraw  3.Balance  4.Apply Interest  5.Exit
# Enter choice: 4
# Interest added: 4.8
#
# 1.Deposit  2.Withdraw  3.Balance  4.Apply Interest  5.Exit
# Enter choice: 3
# Balance: 124.8
#
# 1.Deposit  2.Withdraw  3.Balance  4.Apply Interest  5.Exit
# Enter choice: 2
# Amount: 20
# Withdrawn: 20.0
#
# 1.Deposit  2.Withdraw  3.Balance  4.Apply Interest  5.Exit
# Enter choice: 3
# Balance: 104.8
#
# 1.Deposit  2.Withdraw  3.Balance  4.Apply Interest  5.Exit
# Enter choice: 1
# Amount: 500
# Deposited: 500.0
#
# 1.Deposit  2.Withdraw  3.Balance  4.Apply Interest  5.Exit
# Enter choice: 4
# Interest added: 24.191999999999997
#
# 1.Deposit  2.Withdraw  3.Balance  4.Apply Interest  5.Exit
# Enter choice: 3
# Balance: 628.992
#
# 1.Deposit  2.Withdraw  3.Balance  4.Apply Interest  5.Exit
# Enter choice: 5
